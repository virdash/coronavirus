# %%
# Data manipulation
import pandas as pd # to import csv and for data manipulation
import matplotlib.pyplot as plt # to plot graph
import seaborn as sns # for intractve graphs
import numpy as np # for linear algebra
# import pandas_profiling as pp
import datetime # to dela with date and time
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
import platform; print(platform.platform())
import sys; print("Python", sys.version)
import numpy; print("NumPy", numpy.__version__)
import scipy; print("SciPy", scipy.__version__)
import sklearn; print("Scikit-Learn", sklearn.__version__)
# Out:
# Linux-5.3.0-40-generic-x86_64-with-debian-buster-sid
# Python 3.7.3 (default, Mar 27 2019, 22:11:17)
# [GCC 7.3.0]
# NumPy 1.18.1
# SciPy 1.4.1
# Scikit-Learn 0.20.3

# %%
confirm = pd.read_csv('../app/data/confirm.csv')
recover = pd.read_csv('../app/data/recover.csv')
death = pd.read_csv('../app/data/death.csv')

# confirm = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv')
# recover = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv')
# death = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv')

# %%
confirm.head().T.index
# Out:
# Index(['Unnamed: 0', 'Province/State', 'Country/Region', 'Lat', 'Long',
#        '1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20',
#        '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20',
#        '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20',
#        '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20',
#        '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20',
#        '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20',
#        '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20',
#        '3/13/20'],
#       dtype='object')

# %%
confirm.iloc[:,5:].sum().values
# Out:
# array([   555,    653,    941,   1434,   2118,   2927,   5578,   6166,
#          8234,   9927,  12038,  16787,  19881,  23892,  27635,  30817,
#         34391,  37120,  40150,  42762,  44802,  45221,  60368,  66885,
#         69030,  71224,  73258,  75136,  75639,  76197,  76823,  78579,
#         78965,  79568,  80413,  81395,  82754,  84120,  86011,  88369,
#         90306,  92840,  95120,  97882, 101784, 105821, 109795, 113561,
#        118592, 125865, 128343, 145193])

# %%
recover.head()
# Out:
#   Province/State  Country/Region      Lat      Long  1/22/20  1/23/20  \
# 0          Anhui  Mainland China  31.8257  117.2264        0        0
# 1        Beijing  Mainland China  40.1824  116.4142        0        0
# 2      Chongqing  Mainland China  30.0572  107.8740        0        0
# 3         Fujian  Mainland China  26.0789  117.9874        0        0
# 4          Gansu  Mainland China  36.0611  103.8343        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/19/20  2/20/20  2/21/20  \
# 0        0        0        0        0  ...      413      474      539
# 1        1        2        2        2  ...      145      153      169
# 2        0        0        0        0  ...      274      299      316
# 3        0        0        0        0  ...      112      126      149
# 4        0        0        0        0  ...       65       71       76
#
#    2/22/20  2/23/20  2/24/20  2/25/20  2/26/20  2/27/20  2/28/20
# ...

# %%
death.head()
# Out:
#   Province/State  Country/Region      Lat      Long  1/22/20  1/23/20  \
# 0          Anhui  Mainland China  31.8257  117.2264        0        0
# 1        Beijing  Mainland China  40.1824  116.4142        0        0
# 2      Chongqing  Mainland China  30.0572  107.8740        0        0
# 3         Fujian  Mainland China  26.0789  117.9874        0        0
# 4          Gansu  Mainland China  36.0611  103.8343        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/19/20  2/20/20  2/21/20  \
# 0        0        0        0        0  ...        6        6        6
# 1        0        0        0        1  ...        4        4        4
# 2        0        0        0        0  ...        5        6        6
# 3        0        0        0        0  ...        0        1        1
# 4        0        0        0        0  ...        2        2        2
#
#    2/22/20  2/23/20  2/24/20  2/25/20  2/26/20  2/27/20  2/28/20
# ...

# %%
confirm_info = confirm.ix[:,0:4]

# %%
confirm_last = confirm.ix[:,-1]

# %%
confirm.shape
# Out:
# (114, 42)

# %%
confirm_info['latest'] = confirm_last

# %%
confirm_info['latest'].sum()
# Out:
# 84124

# %%
"{:,.0f}".format(confirm_info['latest'].sum())
# Out:
# '84,124'

# %%
def getLatest(df):
    df_info = df.ix[:,0:4]
    df_last = df.ix[:,-1]
    df_info['latest'] = df_last
    
    return df_info

# %%
getLatest(confirm)
# Out:
#                                   Province/State   Country/Region       Lat  \
# 0                                          Anhui   Mainland China  31.82570
# 1                                        Beijing   Mainland China  40.18240
# 2                                      Chongqing   Mainland China  30.05720
# 3                                         Fujian   Mainland China  26.07890
# 4                                          Gansu   Mainland China  36.06110
# 5                                      Guangdong   Mainland China  23.34170
# 6                                        Guangxi   Mainland China  23.82980
# 7                                        Guizhou   Mainland China  26.81540
# 8                                         Hainan   Mainland China  19.19590
# 9                                          Hebei   Mainland China  38.04280
# 10                                  Heilongjiang   Mainland China  47.86200
# ...

# %%
import tweepy

# %%
API_KEY = 'ZFnnoIcZUusgB4O9JULAYDHBG'
API_SECRET_KEY = 'lvoUVe4XQ7lf0nuBsZVbrazBg7RKwInqDXFSKQxqi0Q80uhOCw'
ACCESS_TOKEN = '409802626-MlmHNIC1W1INQu6tG1fzj7TSdTg7defRrNWlepwF'
ACCESS_TOKEN_SECRET = 'ULtks3TDGEmiM2yLtq411yy3mQb7Lt95uLBBX5HrWGbq0'

# %%
# OAuth process, using the keys and tokens
auth = tweepy.OAuthHandler(API_KEY, API_SECRET_KEY)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

# %%
api = tweepy.API(auth)

# %%
user = api.me()

# %%
user.name
# Out:
# 'Solomon Igori'

# %%
search = tweepy.Cursor(api.search, q="Coronavirus", result_type="recent", lang="en").items(10)

# %%
search

# %%
for item in search:
    print (item.text)
# Out:
# if you listen to gulch ur immune to coronavirus
# RT @paxthedog: I’m still not entirely sure how to process the “coronavirus prevention is actually cultural appropriation” absolute miracle…
# RT @CuomoPrimeTime: Former Democratic Sen. Al Franken on coronavirus says we need to talk "about Donald Trump and how awful he is as not ju…
# RT @ResisterChic: Resident Dies In Matt Gaetz's District After He Mocked Coronavirus
#
# Like tRUMP this guy ain’t just a pr*ck he’s the whole…
# If you're wondering why
# there are 50 deaths, 50 yesterday in South Korea
# and in Italy there were 264 and today is 3… https://t.co/0JiZ8KWR8o
# RT @mredwards: I've heard that coronavirus is going to cause a massive shortage of books, which will be essential when we're all stuck at h…
# RT @henrikenderlein: Coronavirus: Is the outbreak in Italy really *so different* from the outbreak in Germany (as suggested by many)? For w…
# ...

# %%
print(search)
